# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
# %matplotlib notebook

from swing_config import *
from swing_plot import swing_plot
from swing_open_loop import fv_gen

# %%
stat = np.load('./data/stat.npy')

# %%
xx, yy = np.meshgrid(np.linspace(0, 1, len(stat)), np.linspace(0, 1, len(stat)))
fig = plt.figure(figsize=(5,5))
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(xx, yy, np.rad2deg(np.amax(stat, axis=2)))
ax.set_xlabel('$A$')
ax.set_ylabel('$\omega$')
ax.set_title('Responnse magnitude')
# Out:
# <img src="data:image/png;base64,..." width="500">
# Text(0.5,0.92,'Responnse magnitude')

# %%
xx, yy = np.meshgrid(np.linspace(0, 1, len(stat)), np.linspace(0, 1, len(stat)))
fig = plt.figure(figsize=(5,5))
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(xx, yy, np.rad2deg(np.amax(stat, axis=1)))
ax.set_xlabel('$\phi$')
ax.set_ylabel('$A$')
ax.set_title('Responnse magnitude')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="500">

# %%
xx, yy = np.meshgrid(np.linspace(0, 1, len(stat)), np.linspace(0, 1, len(stat)))
fig = plt.figure(figsize=(5,5))
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(xx, yy, np.rad2deg(np.amax(stat, axis=0)))
ax.set_xlabel('$\phi$')
ax.set_ylabel('$\omega$')
ax.set_title('Responnse magnitude')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="500">

# %%
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(xx, yy, np.rad2deg(np.amax(stat, axis=1)))
ax.set_xlabel('$A$')
ax.set_ylabel('$\phi$')
ax.set_title('Responnse magnitude')
plt.show()
# Out:
# Text(0.5,0.92,'Responnse magnitude')

# %%
N = 50
p = np.argmax(stat)
i = p // N // N % N / N # amplitude
j = p // N % N / N      # omega
k = p % N / N           # phi

# %% [markdown]
# For the given swing model, the optimal input signal is
# $$f(t) = A_{max} \sin(1.38 t + 4.5)$$

# %%
from swing_open_loop import open_loop_test
from swing_anim import swing_animation

# %%
sol = open_loop_test(i, j, k)

# %%
swing_animation(sol)
# Out:
# <img src="data:image/png;base64,..." width="600">
