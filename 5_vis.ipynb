# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
# %matplotlib notebook

from swing_config import *
from swing_plot import swing_plot
from swing_open_loop import fv_gen

# %%
stat = np.load('./data/stat.npy')

# %%
np.max(stat, axis=0)
# Out:
# array([[ 0.52359879,  0.52359879,  0.52359879,  0.64399713,  0.52359879],
#        [ 1.03280747,  1.59615076,  1.70236135,  1.43520725,  1.03286123],
#        [ 0.74627417,  0.74346715,  0.70476568,  0.68084908,  0.74627405],
#        [ 0.53874022,  0.62943578,  0.61495471,  0.63672769,  0.53874016],
#        [ 0.53116053,  0.6224736 ,  0.59797424,  0.62804615,  0.53116071]])

# %%
xx, yy = np.meshgrid(np.linspace(0, 1, len(stat)) * ome_max, np.linspace(0, 1, len(stat)) * phi_max)
fig = plt.figure(figsize=(5,5))
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(xx, yy, np.rad2deg(np.amax(stat, axis=0)),
                cmap=cm.coolwarm,
                linewidth=0, 
                antialiased=False)
ax.set_xlabel('$\omega$')
ax.set_ylabel('$\phi$')
ax.set_title('Responnse magnitude')
# Out:
# <img src="data:image/png;base64,..." width="500">
# Text(0.5,0.92,'Responnse magnitude')
